# %%
from docplex.mp.model import Model
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from random import randint, uniform

# %%
gen_data = pd.read_excel("gen_stations.xlsx")

# %%
gen_data.dropna(axis='rows', inplace=True)
gen_data.columns = ['station', 'installed_capacity', 'available_capacity']
gen_data.reset_index(inplace=True)
gen_data.index = gen_data.index+1
gen_data.drop('index', axis=1, inplace=True)

# %%
gen_data['station'] = gen_data['station'].astype('str')

# %%
gen_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 1 to 19
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   station             19 non-null     object
#  1   installed_capacity  19 non-null     float64
#  2   available_capacity  19 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 588.0+ bytes

# %%
gen_data['unused'] = gen_data['installed_capacity'] - gen_data['available_capacity']

# %%
len(gen_data['station'].unique())
# Out:
# 19

# %%
plt.figure(figsize=(11,7))
plt.stackplot(list(gen_data.station.values), gen_data.available_capacity, gen_data['unused'])
plt.ylabel("Capacity (MW)")
plt.xlabel("Generating Stations")
plt.xticks(np.arange(1,20, step=1),rotation=290)
plt.legend(['Available Capacity','Installed Capacity'])
plt.grid()
plt.savefig("generation capacity.png", bbox_inches='tight')

# %%
gen_data
# Out:
#                 station  installed_capacity  available_capacity  unused
# 1         Kanji (Hydro)               760.0               327.0   433.0
# 2         Jebba (Hydro)               578.4               351.0   227.4
# 3       Shiroro (Hydro)               600.0               600.0     0.0
# 4         Egbin (Steam)              1320.0              1100.0   220.0
# 5        Sapele (Steam)               720.0               120.0   600.0
# 6           Delta (Gas)               900.0               604.0   296.0
# 7       Afam IV&V (Gas)               351.0               120.0   231.0
# 8         Afam VI (Gas)               650.0               576.0    74.0
# 9           Sapele NIPP               500.0               112.0   388.0
# 10          Geregu NIPP               450.0               435.0    15.0
# 11           Geregu Gas               450.0               435.0    15.0
# 12       Omotosho (Gas)               335.0               304.0    31.0
# 13  Omotosho NIPP (Gas)               500.0               360.0   140.0
# 14    Alaoji NIPP (Gas)               500.0               360.0   140.0
# 15     Olorunsogo (Gas)               335.0               240.0    95.0
# 16      Olorunsogo NIPP               750.0               300.0   450.0
# 17      Azura IPP (Gas)               461.0               450.0    11.0
# 18    Okpai (Gas/Steam)               480.0               300.0   180.0
# 19              Ihovbor               500.0               270.0   230.0

# %%
gen_data['station'] = [each_item.split('(')[0].strip() for each_item in gen_data['station']]

# %%
gen_data
# Out:
#             station  installed_capacity  available_capacity  unused
# 1             Kanji               760.0               327.0   433.0
# 2             Jebba               578.4               351.0   227.4
# 3           Shiroro               600.0               600.0     0.0
# 4             Egbin              1320.0              1100.0   220.0
# 5            Sapele               720.0               120.0   600.0
# 6             Delta               900.0               604.0   296.0
# 7         Afam IV&V               351.0               120.0   231.0
# 8           Afam VI               650.0               576.0    74.0
# 9       Sapele NIPP               500.0               112.0   388.0
# 10      Geregu NIPP               450.0               435.0    15.0
# 11       Geregu Gas               450.0               435.0    15.0
# 12         Omotosho               335.0               304.0    31.0
# 13    Omotosho NIPP               500.0               360.0   140.0
# 14      Alaoji NIPP               500.0               360.0   140.0
# 15       Olorunsogo               335.0               240.0    95.0
# 16  Olorunsogo NIPP               750.0               300.0   450.0
# 17        Azura IPP               461.0               450.0    11.0
# 18            Okpai               480.0               300.0   180.0
# 19          Ihovbor               500.0               270.0   230.0

# %% [markdown]
# ### Linear Programming with assummed cost

# %%
#According to article, the average levelised cost of On-Grid Electricity Generation was randomized
# $0.05kWh ~ $0.12/kWh == $0.05*10(^-3)MWh ~ $0.12*10(^-3)MWh
# randomly generate cost of generation
cost = [uniform(0.05*0.001, 0.12*0.001) for i in range(19)]

# %%
gen_data['cost($)/MWh'] = cost

# %%
### The sections below works with the randomly generated cost I once generated
gen_data = pd.read_csv("gen_data.csv", index_col=0)

# %%
gen_data
# Out:
#             station  installed_capacity  available_capacity  unused  \
# 1             Kanji               760.0               327.0   433.0
# 2             Jebba               578.4               351.0   227.4
# 3           Shiroro               600.0               600.0     0.0
# 4             Egbin              1320.0              1100.0   220.0
# 5            Sapele               720.0               120.0   600.0
# 6             Delta               900.0               604.0   296.0
# 7         Afam IV&V               351.0               120.0   231.0
# 8           Afam VI               650.0               576.0    74.0
# 9       Sapele NIPP               500.0               112.0   388.0
# 10      Geregu NIPP               450.0               435.0    15.0
# 11       Geregu Gas               450.0               435.0    15.0
# 12         Omotosho               335.0               304.0    31.0
# 13    Omotosho NIPP               500.0               360.0   140.0
# 14      Alaoji NIPP               500.0               360.0   140.0
# 15       Olorunsogo               335.0               240.0    95.0
# 16  Olorunsogo NIPP               750.0               300.0   450.0
# 17        Azura IPP               461.0               450.0    11.0
# 18            Okpai               480.0               300.0   180.0
# 19          Ihovbor               500.0               270.0   230.0
#
#     cost($)/MWh
# 1      0.000068
# 2      0.000079
# 3      0.000113
# 4      0.000104
# 5      0.000093
# 6      0.000104
# 7      0.000108
# 8      0.000068
# 9      0.000081
# 10     0.000119
# 11     0.000097
# 12     0.000077
# 13     0.000090
# 14     0.000068
# 15     0.000117
# 16     0.000098
# 17     0.000086
# 18     0.000111
# 19     0.000064

# %%
# gen_data.to_csv("gen_data.csv")

# %%
## Initiate model
mdl = Model(name="Generation", cts_by_name=True)

# %%
def label_generators_and_set_constraint(data_frame):
    c_vars = []
    for ind in data_frame.index:
        desg_name = data_frame['station'][ind]
        des_name = desg_name
        # label the variables
        #g1,g2,g3,g4....
        desg_name = mdl.continuous_var(name=str(desg_name))
        c_vars.append(desg_name)
        #set the available capacity of each generator as constraints
        desg_constraint = data_frame['available_capacity'][ind]
        desg_x_constraint = mdl.add_constraint(desg_name<=desg_constraint, des_name)
        
    # set contraint for the maximum transmission
    # add tranmission capacity as constraint
    transmission_cap = 8100
    # g1+g2+g3+... <= 8100
    trans_cap = mdl.add_constraint(mdl.sum(c_vars) <= transmission_cap, "transmission_cap" )
    demand_cap = 19798
    demand_cap = mdl.add_constraint(mdl.sum(c_vars) <= demand_cap, "demand" )
    return c_vars

# %%
# name each generator and set the generation limit
c_vars = label_generators_and_set_constraint(gen_data)

# %%
# contraints overview
for each in mdl.iter_constraints():
    print(each)
# Out:
# Kanji: Kanji <= 327.0
# Jebba: Jebba <= 351.0
# Shiroro: Shiroro <= 600.0
# Egbin: Egbin <= 1100.0
# Sapele: Sapele <= 120.0
# Delta: Delta <= 604.0
# Afam IV&V: Afam IV&V <= 120.0
# Afam VI: Afam VI <= 576.0
# Sapele NIPP: Sapele NIPP <= 112.0
# Geregu NIPP: Geregu NIPP <= 435.0
# Geregu Gas: Geregu Gas <= 435.0
# Omotosho: Omotosho <= 304.0
# Omotosho NIPP: Omotosho NIPP <= 360.0
# Alaoji NIPP: Alaoji NIPP <= 360.0
# Olorunsogo: Olorunsogo <= 240.0
# Olorunsogo NIPP: Olorunsogo NIPP <= 300.0
# Azura IPP: Azura IPP <= 450.0
# Okpai: Okpai <= 300.0
# Ihovbor: Ihovbor <= 270.0
# transmission_cap: Kanji+Jebba+Shiroro+Egbin+Sapele+Delta+Afam IV&V+Afam VI+Sapele NIPP+Geregu NIPP+Geregu Gas+Omotosho+Omotosho NIPP+Alaoji NIPP+Olorunsogo+Olorunsogo NIPP+Azura IPP+Okpai+Ihovbor <= 8100
# demand: Kanji+Jebba+Shiroro+Egbin+Sapele+Delta+Afam IV&V+Afam VI+Sapele NIPP+Geregu NIPP+Geregu Gas+Omotosho+Omotosho NIPP+Alaoji NIPP+Olorunsogo+Olorunsogo NIPP+Azura IPP+Okpai+Ihovbor <= 19798

# %%
c_vars
# Out:
# [docplex.mp.Var(type=C,name='Kanji'),
#  docplex.mp.Var(type=C,name='Jebba'),
#  docplex.mp.Var(type=C,name='Shiroro'),
#  docplex.mp.Var(type=C,name='Egbin'),
#  docplex.mp.Var(type=C,name='Sapele'),
#  docplex.mp.Var(type=C,name='Delta'),
#  docplex.mp.Var(type=C,name='Afam IV&V'),
#  docplex.mp.Var(type=C,name='Afam VI'),
#  docplex.mp.Var(type=C,name='Sapele NIPP'),
#  docplex.mp.Var(type=C,name='Geregu NIPP'),
#  docplex.mp.Var(type=C,name='Geregu Gas'),
#  docplex.mp.Var(type=C,name='Omotosho'),
#  docplex.mp.Var(type=C,name='Omotosho NIPP'),
#  docplex.mp.Var(type=C,name='Alaoji NIPP'),
#  docplex.mp.Var(type=C,name='Olorunsogo'),
#  docplex.mp.Var(type=C,name='Olorunsogo NIPP'),
#  docplex.mp.Var(type=C,name='Azura IPP'),
#  docplex.mp.Var(type=C,name='Okpai'),
#  docplex.mp.Var(type=C,name='Ihovbor')]

# %%
mdl.get_constraint_by_name('Kanji')
# Out:
# docplex.mp.LinearConstraint[Kanji](Kanji,LE,327.0)

# %%
cost_per_mw = gen_data['cost($)/MWh']

# %%
total_cost_obj = (cost_per_mw[1]*c_vars[0]+
             cost_per_mw[2]*c_vars[1]+
             cost_per_mw[3]*c_vars[2]+
             cost_per_mw[4]*c_vars[3]+
             cost_per_mw[5]*c_vars[4]+
             cost_per_mw[6]*c_vars[5]+
             cost_per_mw[7]*c_vars[6]+
             cost_per_mw[8]*c_vars[7]+
             cost_per_mw[9]*c_vars[8]+
             cost_per_mw[10]*c_vars[9]+
             cost_per_mw[11]*c_vars[10]+
             cost_per_mw[12]*c_vars[11]+
             cost_per_mw[13]*c_vars[12]+
             cost_per_mw[14]*c_vars[13]+
             cost_per_mw[15]*c_vars[14]+
             cost_per_mw[16]*c_vars[15]+
             cost_per_mw[17]*c_vars[16]+
             cost_per_mw[18]*c_vars[17]+
             cost_per_mw[19]*c_vars[18]
            )

# %%
## Adding the budget restriction constraint
budget_restriction = mdl.add_constraints([total_cost_obj >= 0.3, total_cost_obj<=1], ["budget_lim_1", "budget_lim_2"])

# %%
mdl.minimize(total_cost_obj)

# %%
print(mdl.number_of_constraints)
# Out:
# 23

# %%
solution = mdl.solve()

# %%
solution.display()
# Out:
# solution for: Generation
# objective: 0.300
# status: OPTIMAL_SOLUTION(2)
# Kanji = 327.000
# Jebba = 351.000
# Shiroro = 600.000
# Egbin = 1100.000
# Sapele = 120.000
# Delta = 538.948

# %% [markdown]
# ### Using another approach

# %%
from pulp import *

# %%
cost_per_mw
# Out:
# 1     0.000068
# 2     0.000079
# 3     0.000113
# 4     0.000104
# 5     0.000093
# 6     0.000104
# 7     0.000108
# 8     0.000068
# 9     0.000081
# 10    0.000119
# 11    0.000097
# 12    0.000077
# 13    0.000090
# 14    0.000068
# 15    0.000117
# 16    0.000098
# 17    0.000086
# 18    0.000111
# 19    0.000064
# Name: cost($)/MWh, dtype: float64

# %%
class PulpModelling():
    def __init__(self, data_frame):
        prob = LpProblem("Generation", LpMaximize)
        self.data_frame = data_frame
        self.prob = prob
        self.nm_list = []
    def set_objective(self):
        for ind, each_cost in zip(self.data_frame.index, self.data_frame['cost($)/MWh']):
            desg_name = self.data_frame['station'][ind]
            des_name = desg_name
            # label the variables
            #g1,g2,g3,g4....
            desg_name = LpVariable(str(desg_name), lowBound=0)
            self.nm_list.append(desg_name)
            self.prob += each_cost*desg_name
    def set_constraint(self):
        for ind, each_var in zip(self.data_frame.index, self.nm_list):
            #set the available capacity of each generator as constraints
            desg_constraint = self.data_frame['available_capacity'][ind]
            self.prob += each_var<=desg_constraint
    def get_pulp_model(self):
        return self.prob

# %%
new_mdl = PulpModelling(gen_data)

# %%
new_mdl.set_objective()

# %%
new_mdl.set_constraint()

# %%
prob = new_mdl.get_pulp_model()

# %%
prob
# Out:
# Generation:
# MAXIMIZE
# 6.418703219969852e-05*Ihovbor + 0.0
# SUBJECT TO
# _C1: Kanji <= 327
#
# _C2: Jebba <= 351
#
# _C3: Shiroro <= 600
#
# _C4: Egbin <= 1100
#
# _C5: Sapele <= 120
#
# _C6: Delta <= 604
#
# _C7: Afam_IV&V <= 120
#
# _C8: Afam_VI <= 576
#
# _C9: Sapele_NIPP <= 112
#
# _C10: Geregu_NIPP <= 435
#
# _C11: Geregu_Gas <= 435
#
# _C12: Omotosho <= 304
#
# _C13: Omotosho_NIPP <= 360
#
# _C14: Alaoji_NIPP <= 360
#
# _C15: Olorunsogo <= 240
#
# _C16: Olorunsogo_NIPP <= 300
#
# _C17: Azura_IPP <= 450
#
# _C18: Okpai <= 300
#
# _C19: Ihovbor <= 270
#
# VARIABLES
# Afam_IV&V Continuous
# Afam_VI Continuous
# Alaoji_NIPP Continuous
# Azura_IPP Continuous
# Delta Continuous
# Egbin Continuous
# Geregu_Gas Continuous
# Geregu_NIPP Continuous
# Ihovbor Continuous
# Jebba Continuous
# Kanji Continuous
# Okpai Continuous
# Olorunsogo Continuous
# Olorunsogo_NIPP Continuous
# Omotosho Continuous
# Omotosho_NIPP Continuous
# Sapele Continuous
# Sapele_NIPP Continuous
# Shiroro Continuous

# %%
status = prob.solve()

# %%
LpStatus[status]
# Out:
# 'Optimal'

# %%
value(prob.objective)
# Out:
# 0.0173304986939186
